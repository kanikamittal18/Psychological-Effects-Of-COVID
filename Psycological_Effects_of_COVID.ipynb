# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
! pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-605fdd36-7ceb-4eef-bd06-f97a3f435ce7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-605fdd36-7ceb-4eef-bd06-f97a3f435ce7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d hemanthhari/psycological-effects-of-covid
# Out:
# ...
#   0% 0.00/7.64k [00:00<?, ?B/s]
# 100% 7.64k/7.64k [00:00<00:00, 15.3MB/s]

# %%
# !unzip psycological-effects-of-covid.zip
# Out:
# Archive:  psycological-effects-of-covid.zip
#   inflating: psyco.csv

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("/content/psycological-effects-of-covid.zip")

# %%
df.head(5)
# Out:
#       age  gender          occupation line_of_work  time_bp  time_dp  \
# 0   19-25    Male  Student in College          NaN        7        5
# 1  Dec-18    Male   Student in School          NaN        7       11
# 2   19-25    Male  Student in College          NaN        7        7
# 3   19-25    Male  Student in College          NaN        7        7
# 4   19-25  Female  Student in College          NaN        7        7
#
#    travel_time  easeof_online  home_env  prod_inc  ...  fam_connect  relaxed  \
# 0          0.5              3         3       0.0  ...          1.0     -0.5
# 1          0.5              4         2      -0.5  ...          1.0      1.0
# 2          1.5              2         2       1.0  ...          0.5      0.5
# 3          1.5              3         1       0.0  ...          0.0     -1.0
# 4          1.5              2         2       0.0  ...          0.0      0.5
#
#    self_time  like_hw  dislike_hw                        prefer  \
# ...

# %%
df = df.drop(columns=['Unnamed: 19', 'time_bp.1', 'travel+work'])
df.describe(include='all')
# Out:
#           age gender            occupation line_of_work      time_bp  \
# count    1175   1175                  1175          479  1175.000000
# unique      7      3                     8            8          NaN
# top     19-25   Male  Working Professional     Teaching          NaN
# freq      345    649                   479          217          NaN
# mean      NaN    NaN                   NaN          NaN     7.415319
# std       NaN    NaN                   NaN          NaN     2.005385
# min       NaN    NaN                   NaN          NaN     4.000000
# 25%       NaN    NaN                   NaN          NaN     5.000000
# 50%       NaN    NaN                   NaN          NaN     7.000000
# 75%       NaN    NaN                   NaN          NaN     9.000000
# max       NaN    NaN                   NaN          NaN    12.000000
#
#             time_dp  travel_time  easeof_online     home_env     prod_inc  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings("ignore")

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['gender'].value_counts(), labels=df['gender'].value_counts().index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['prefer'].value_counts(), labels=df['prefer'].value_counts().index, autopct='%1.1f%%')
plt.title('Preference for Attendance Mode')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['occupation'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Occupation Distribution')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['line_of_work'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Line of Work Distribution')
plt.xlabel('Line of Work')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['time_bp'], bins=10, color='skyblue', edgecolor='black')
plt.title('Time Before Pandemic Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['time_dp'], bins=10, color='skyblue', edgecolor='black')
plt.title('Time During Pandemic Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['travel_time'], bins=10, color='skyblue', edgecolor='black')
plt.title('Travel Time Distribution')
plt.xlabel('Time (hours)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['easeof_online'], bins=5, color='skyblue', edgecolor='black')
plt.title('Ease of Online Work Distribution')
plt.xlabel('Ease Score')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['home_env'], bins=5, color='skyblue', edgecolor='black')
plt.title('Home Environment Score Distribution')
plt.xlabel('Home Environment Score')
plt.ylabel('Count')
plt.show()

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
fig, ax = plt.subplots(figsize=(14, 11))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.title('Correlation Matrix')
plt.show()

# %%
fig, axs = plt.subplots(6, 1, figsize=(10, 40))

sns.boxplot(y=df['prod_inc'], ax=axs[0], color='skyblue')
axs[0].set_title('Productivity Increase Distribution')

sns.boxplot(y=df['sleep_bal'], ax=axs[1], color='skyblue')
axs[1].set_title('Sleep Balance Distribution')

sns.boxplot(y=df['new_skill'], ax=axs[2], color='skyblue')
axs[2].set_title('New Skill Acquisition Distribution')

sns.boxplot(y=df['fam_connect'], ax=axs[3], color='skyblue')
axs[3].set_title('Family Connection Distribution')
sns.boxplot(y=df['relaxed'], ax=axs[4], color='skyblue')
axs[4].set_title('Relaxation Distribution')

sns.boxplot(y=df['self_time'], ax=axs[5], color='skyblue')
axs[5].set_title('Self Time Distribution')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(4, 1, figsize=(10, 30))

sns.countplot(x='occupation', hue='gender', data=df, ax=axs[0], palette='viridis')
axs[0].set_title('Occupation by Gender')
axs[0].set_xlabel('Occupation')
axs[0].set_ylabel('Count')
axs[0].tick_params(axis='x', rotation=45)

sns.countplot(x='prefer', hue='gender', data=df, ax=axs[1], palette='viridis')
axs[1].set_title('Preference for Attendance Mode by Gender')
axs[1].set_xlabel('Preference')
axs[1].set_ylabel('Count')

sns.violinplot(x='gender', y='home_env', data=df, ax=axs[2], palette='viridis')
axs[2].set_title('Home Environment Score by Gender')
axs[2].set_xlabel('Gender')
axs[2].set_ylabel('Home Environment Score')
sns.violinplot(x='gender', y='easeof_online', data=df, ax=axs[3], palette='viridis')
axs[3].set_title('Ease of Online Work by Gender')
axs[3].set_xlabel('Gender')
axs[3].set_ylabel('Ease of Online Work Score')

plt.tight_layout()
plt.show()

# %%
data = df.copy()

# %%
change_columns = ['prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed', 'self_time']
data['lifestyle_change'] = data[change_columns].apply(lambda row: np.any(np.abs(row) > 0.5), axis=1).astype(int)

data.head(10)
# Out:
#       age  gender          occupation line_of_work  time_bp  time_dp  \
# 0   19-25    Male  Student in College          NaN        7        5
# 1  Dec-18    Male   Student in School          NaN        7       11
# 2   19-25    Male  Student in College          NaN        7        7
# 3   19-25    Male  Student in College          NaN        7        7
# 4   19-25  Female  Student in College          NaN        7        7
# 5   19-25    Male  Student in College          NaN        5        7
# 6   19-25    Male  Student in College          NaN        5        4
# 7   19-25    Male  Student in College          NaN        7        9
# 8   19-25    Male  Student in College          NaN        5        9
# 9   19-25    Male  Student in College          NaN        7        7
#
#    travel_time  easeof_online  home_env  prod_inc  sleep_bal  new_skill  \
# 0          0.5              3         3       0.0        0.0        0.5
# ...

# %%
data['lifestyle_change'].value_counts(normalize=True)
# Out:
# 1    0.64766
# 0    0.35234
# Name: lifestyle_change, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).drop(columns='lifestyle_change').columns
numerical_transformer = StandardScaler()

categorical_cols = data.select_dtypes(include=['object']).columns
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
X = data.drop(columns='lifestyle_change')
y = data['lifestyle_change']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

preprocessor.fit(X_train)
X_train = preprocessor.transform(X_train)
X_test = preprocessor.transform(X_test)

X_train.shape, X_test.shape
# Out:
# ((940, 45), (235, 45))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
model = LogisticRegression(random_state=0)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy: ", accuracy * 100)
print("\nClassification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  84.25531914893617
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.68      0.76        85
#            1       0.84      0.93      0.88       150
#
#     accuracy                           0.84       235
#    macro avg       0.85      0.81      0.82       235
# weighted avg       0.84      0.84      0.84       235

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy: ", accuracy * 100)
print("\nClassification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  97.44680851063829
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97        85
#            1       0.99      0.97      0.98       150
#
#     accuracy                           0.97       235
#    macro avg       0.97      0.97      0.97       235
# weighted avg       0.97      0.97      0.97       235

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy: ", accuracy * 100)
print("\nClassification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  99.14893617021276
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        85
#            1       0.99      0.99      0.99       150
#
#     accuracy                           0.99       235
#    macro avg       0.99      0.99      0.99       235
# weighted avg       0.99      0.99      0.99       235

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
